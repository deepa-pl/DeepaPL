# %%
# %matplotlib inline # to plot within the notebook, to get the full view
import matplotlib.pyplot as plt

# %%
plt.plot([0,1,2,3,4],[10,20,30,40,50]);

# %%
y = [12,76,12,54];
x = [1,2,3,4];
plt.plot(x,y);

# %%
plt.hist(y);
